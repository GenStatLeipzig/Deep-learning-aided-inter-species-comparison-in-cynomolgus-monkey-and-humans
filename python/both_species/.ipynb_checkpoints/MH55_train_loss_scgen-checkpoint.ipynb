# %%
import numpy as np
import scanpy as sc
import seaborn as sns
import os
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import sys
path_helper = ["C:\\","Users","vfriedrich","projects","monkey_IZI","git_documentation","scRNAseq_cross_species_primate_human","analysis","helper"]
sys.path.append(os.path.join(*path_helper))
import helperVDF as h
#import decoupler
print(sys.executable)
import torchmetrics
#import scgen
import numpy as np
import scanpy as sc
import seaborn as sns
import os
import pandas as pd
import matplotlib.pyplot as plt
import scipy.sparse as sp
from scipy.spatial.distance import cdist
import warnings

import sys
print(sys.executable)
import scgen
# Out:
# C:\Users\vfriedrich\Anaconda3\envs\scgen\python.exe
# C:\Users\vfriedrich\Anaconda3\envs\scgen\python.exe

# %%
pre = "MH55"
drive = 'F'
base_model_path,base_table_path,base_plots_path,base_anndata_objects = h.return_local_paths(drive = drive,
                                                                              pre = pre,
                                                                              add_path = True)

# %% [markdown]
# ### MH49_c

# %%
model_path = os.path.join(*["F:\\","monkey_IZI","analysis","cluster_runs","workspace-runVAE",
                            "output","MH49_c","models"])
model_dir_names = os.listdir(model_path)

# %%
warnings.filterwarnings("ignore")
df_hyper = {}
for model_dir_name in model_dir_names:
    load_string = os.path.join(model_path,model_dir_name,'MH49_c_scgen_model_' + str(model_dir_name)+'.pt')
    model = scgen.SCGEN.load(load_string)
    df_ct = model.history['train_loss_epoch'].join(model.history['validation_loss'])
    df_hyper[model_dir_name] = df_ct
# Out:
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 4161 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 2981 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 1753 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 19084 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 7480 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 1143 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 7607 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 7727 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.

# %%
col_train = "#e78429"
col_val = "#381a61"

# %%
fig, axs = plt.subplots(2, 4, figsize=(12, 6))
axs = axs.flatten()
for loc, key in enumerate(df_hyper):
    axs[loc].plot(df_hyper[key]['train_loss_epoch'], label='train', color=col_train)
    axs[loc].plot(df_hyper[key]['validation_loss'], label='validation', color=col_val)
    axs[loc].set_xlabel('epoch', fontsize=11)
    axs[loc].set_ylabel('loss', fontsize=11)
    axs[loc].legend()
    #nlat = key.split('nlat')[1].split('_')[0]
    #bs = key.split('bs')[1].split('.')[0]
    axs[loc].set_title(key.split('.')[0].split('_')[-1]) 
    
plt.tight_layout()
plt.savefig(os.path.join(base_plots_path,pre + 'loss_curves_scgen_all_MH49_c.pdf'),bbox_inches = 'tight')

# %% [markdown]
# ### MH50_c

# %%
model_path = os.path.join(*["F:\\","monkey_IZI","analysis","cluster_runs","workspace-runVAE",
                            "output","MH50_c","models"])
model_dir_names = os.listdir(model_path)

# %%
warnings.filterwarnings("ignore")
df_hyper = {}
for model_dir_name in model_dir_names:
    load_string = os.path.join(model_path,model_dir_name,'MH50_c_scgen_model_' + str(model_dir_name)+'.pt')
    model = scgen.SCGEN.load(load_string)
    df_ct = model.history['train_loss_epoch'].join(model.history['validation_loss'])
    df_hyper[model_dir_name] = df_ct
# Out:
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 1652 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 1532 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 650 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 9122 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 2769 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 512 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 4666 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 4734 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.

# %%
fig, axs = plt.subplots(2, 4, figsize=(12, 6))
axs = axs.flatten()
for loc, key in enumerate(df_hyper):
    axs[loc].plot(df_hyper[key]['train_loss_epoch'], label='train', color=col_train)
    axs[loc].plot(df_hyper[key]['validation_loss'], label='validation', color=col_val)
    axs[loc].set_xlabel('epoch', fontsize=11)
    axs[loc].set_ylabel('loss', fontsize=11)
    axs[loc].legend()
    #nlat = key.split('nlat')[1].split('_')[0]
    #bs = key.split('bs')[1].split('.')[0]
    axs[loc].set_title(key.split('.')[0].split('_')[-1]) 
    
plt.tight_layout()
plt.savefig(os.path.join(base_plots_path,pre + 'loss_curves_scgen_pp_rep_MH50_c.pdf'),bbox_inches = 'tight')

# %% [markdown]
# ## MH51_c

# %%
model_path = os.path.join(*["F:\\","monkey_IZI","analysis","cluster_runs","workspace-runVAE",
                            "output","MH51_c","models"])
model_dir_names = os.listdir(model_path)

# %%
warnings.filterwarnings("ignore")
df_hyper = {}
for model_dir_name in model_dir_names:
    load_string = os.path.join(model_path,model_dir_name,'MH51_c_scgen_model_' + str(model_dir_name)+'.pt')
    model = scgen.SCGEN.load(load_string)
    df_ct = model.history['train_loss_epoch'].join(model.history['validation_loss'])
    df_hyper[model_dir_name] = df_ct
# Out:
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 2061 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 1533 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 885 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 9578 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 3725 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 562 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 3762 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 3816 cells, 939 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.

# %%
fig, axs = plt.subplots(2, 4, figsize=(12, 6))
axs = axs.flatten()
for loc, key in enumerate(df_hyper):
    axs[loc].plot(df_hyper[key]['train_loss_epoch'], label='train', color=col_train)
    axs[loc].plot(df_hyper[key]['validation_loss'], label='validation', color=col_val)
    axs[loc].set_xlabel('epoch', fontsize=11)
    axs[loc].set_ylabel('loss', fontsize=11)
    axs[loc].legend()
    #nlat = key.split('nlat')[1].split('_')[0]
    #bs = key.split('bs')[1].split('.')[0]
    axs[loc].set_title(key.split('.')[0].split('_')[-1]) 
    
plt.tight_layout()
plt.savefig(os.path.join(base_plots_path,pre + 'loss_curves_scgen_pp_ran_MH51_c.pdf'),bbox_inches = 'tight')

# %%
base_package_version_path = h.return_package_version_local_path(drive=drive)
h.save_package_versions(base_package_version_path,pre,do_print = True)
h.print_main_versions()
# Out:
# babel==2.11.0
# brotli==1.0.9
# cython==3.0.10
# jinja2==3.1.2
# markdown==3.4.3
# markupsafe==2.1.1
# pillow==10.0.0
# pysocks==1.7.1
# pyyaml==5.4.1
# pygments==2.15.1
# send2trash==1.8.0
# werkzeug==2.3.6
# absl-py==1.4.0
# adjusttext==0.8
# aiohttp==3.8.4
# aiosignal==1.3.1
# anndata==0.9.1
# anyio==3.5.0
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==2.0.5
# async-lru==2.0.4
# async-timeout==4.0.2
# attrs==23.1.0
# backcall==0.2.0
# beautifulsoup4==4.12.2
# bleach==4.1.0
# blosc2==2.0.0
# cachetools==5.3.1
# certifi==2023.5.7
# cffi==1.15.1
# charset-normalizer==3.2.0
# cloudpickle==3.0.0
# colorama==0.4.6
# comm==0.1.2
# contourpy==1.1.0
# cycler==0.11.0
# debugpy==1.5.1
# decorator==5.1.1
# defusedxml==0.7.1
# docrep==0.3.2
# entrypoints==0.4
# et-xmlfile==1.1.0
# executing==0.8.3
# fastjsonschema==2.16.2
# filelock==3.12.2
# fonttools==4.41.0
# fqdn==1.5.1
# frozenlist==1.4.0
# fsspec==2023.6.0
# future==0.18.3
# google-auth==2.22.0
# google-auth-oauthlib==1.0.0
# grpcio==1.56.0
# h11==0.14.0
# h5py==3.9.0
# httpcore==1.0.2
# httpx==0.27.0
# idna==3.4
# importlib-metadata==6.0.0
# importlib-resources==5.2.0
# ipykernel==6.19.2
# ipython==8.12.0
# ipython-genutils==0.2.0
# ipywidgets==8.0.7
# isoduration==20.11.0
# jedi==0.18.1
# joblib==1.3.1
# json5==0.9.6
# jsonpointer==3.0.0
# jsonschema==4.23.0
# jsonschema-specifications==2023.7.1
# jupyter-client==7.4.9
# jupyter-core==5.3.0
# jupyter-events==0.6.3
# jupyter-lsp==2.2.0
# jupyter-server==2.5.0
# jupyter-server-terminals==0.4.4
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==3.0.8
# kiwisolver==1.4.4
# lightning-utilities==0.9.0
# llvmlite==0.40.1
# lxml==4.9.2
# markdown-it-py==3.0.0
# matplotlib==3.7.2
# matplotlib-inline==0.1.6
# matplotlib-venn==1.1.1
# mdurl==0.1.2
# mistune==0.8.4
# mpmath==1.3.0
# msgpack==1.0.8
# multidict==6.0.4
# natsort==8.4.0
# nbclassic==0.5.5
# nbclient==0.5.13
# nbconvert==6.5.4
# nbformat==5.10.4
# nest-asyncio==1.5.6
# networkx==3.1
# notebook==6.5.2
# notebook-shim==0.2.2
# numba==0.57.1
# numexpr==2.8.6
# numpy==1.24.4
# oauthlib==3.2.2
# openpyxl==3.1.2
# opt-einsum==3.3.0
# packaging==23.0
# pandas==1.4.0
# pandocfilters==1.5.0
# parso==0.8.3
# patsy==0.5.3
# pickleshare==0.7.5
# pip==23.1.2
# pkgutil-resolve-name==1.3.10
# platformdirs==2.5.2
# prometheus-client==0.14.1
# prompt-toolkit==3.0.36
# protobuf==4.23.4
# psutil==5.9.0
# pure-eval==0.2.2
# pydeprecate==0.3.0
# py-cpuinfo==9.0.0
# pyasn1==0.5.0
# pyasn1-modules==0.3.0
# pycparser==2.21
# pydevd==3.1.0
# pynndescent==0.5.10
# pyparsing==3.0.9
# pyro-api==0.1.2
# pyro-ppl==1.8.5
# pyrsistent==0.18.0
# python-dateutil==2.8.2
# python-json-logger==2.0.7
# pytorch-lightning==1.3.8
# pytz==2023.3
# pywin32==305.1
# pywinpty==2.0.10
# pyzmq==24.0.1
# referencing==0.30.2
# requests==2.31.0
# requests-oauthlib==1.3.1
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rich==13.4.2
# rpds-py==0.10.6
# rsa==4.9
# scanpy==1.9.3
# scgen==2.0.0
# scikit-learn==1.3.0
# scipy==1.10.1
# scvi-tools==0.13.0
# seaborn==0.12.2
# session-info==1.0.0
# setuptools==59.5.0
# shap==0.44.1
# sinfo==0.3.4
# six==1.16.0
# slicer==0.0.7
# sniffio==1.2.0
# soupsieve==2.4
# stack-data==0.2.0
# statsmodels==0.14.0
# stdlib-list==0.9.0
# sympy==1.12
# tables==3.8.0
# tensorboard==2.13.0
# tensorboard-data-server==0.7.1
# terminado==0.17.1
# threadpoolctl==3.2.0
# tinycss2==1.2.1
# tomli==2.0.1
# torch==2.0.1
# torchmetrics==0.7.1
# tornado==6.2
# tqdm==4.65.0
# traitlets==5.7.1
# types-python-dateutil==2.9.0.20241003
# typing-extensions==4.6.3
# tzdata==2023.3
# umap-learn==0.5.3
# uri-template==1.3.0
# urllib3==1.26.16
# wcwidth==0.2.5
# webcolors==24.8.0
# webencodings==0.5.1
# websocket-client==0.58.0
# wheel==0.38.4
# widgetsnbextension==4.0.8
# win-inet-pton==1.1.0
# yarl==1.9.2
# zipp==3.11.0
# scanpy==1.9.3 anndata==0.9.1 umap==0.5.3 numpy==1.24.4 scipy==1.10.1 pandas==1.4.0 scikit-learn==1.3.0 statsmodels==0.14.0 pynndescent==0.5.10
